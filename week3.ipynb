# %% [markdown]
# ## DAY 1

# %% [markdown]
# ### MATPLOTLIB
# #### Matplotlib is a widely used Python library for creating static, animated, and interactive visualizations, such as graphs and charts

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6]
y=[2,4,6,8,10,12]

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y,color='blue',marker='D',ms=8,markerfacecolor='red',linestyle='--')
plt.xlabel('x values')
plt.ylabel('y values')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### figure v/s axes
# #### figure
# ##### *The Figure is the top-level container for all plot elements in Matplotlib; it acts as the canvas that holds everything.
# ##### *A single Figure can contain one or multiple Axes objects, as well as titles, legends, and other annotations.
#
# #### axes
# ##### *Axes are the actual regions within a Figure where data is plotted, sometimes called subplots
# ##### *Each Axes manages its own x- and y-axis (or z for 3D), labels, title, tick marks, and the graphical details of the data

# %%
fig,ax=plt.subplots()
ax.set_title('Simple line plot')
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()  # This creates a Figure and one Axes (the plot area)
ax.plot([1, 2, 3], [1, 4, 9])  # Plot a simple line
plt.show()

# %%
x=[0,1,2,3,4]
y1=[i for i in x]
y2=[i*2 for i in x]
plt.plot(x,y1,label='linear')
plt.plot(y1,y2,label='quadratic')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y1)
plt.savefig('plotting_eg.png')

# %%
x=[1,2,3,4,5]
y1=[2,4,6,8,10]
y2=[1,3,5,7,9]
plt.plot(x,y1,color='red',marker='H',ms=8,label='Double')
plt.plot(x,y2,color='blue',marker='^',label='odd')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=[1,2,3,4,5]
y=[i**3 for i in x]
plt.plot(x,y,color='green',linestyle='--',marker='o' ,label='cube plot')
plt.legend()
plt.style.use('dark_background')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y1,color='cyan',marker='o')
plt.show()

# %%
plt.figure(figsize=(4,6))
plt.plot([1,2,3,4],[10,20,30,40],marker='o',color='pink',label='data')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True,linestyle=':',color='gray')
plt.text(3,15,'note point',fontsize=9,color='blue')
plt.show()

# %% [markdown]
# ### DAY 2
# #### SCATTER PLOT
# ##### A scatter plot in Matplotlib is a graphical representation used to visualize the relationship between two numerical variables by plotting individual data points on a Cartesian plane using their x and y coordinates.

# %%
plt.scatter([1,2,3,4,5],[5,7,8,5,2],color='cyan')
plt.title('scatter plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
heights=[150,155,345,221,904,544,342,321]
weights=[50,45,65,67,39,78,67,49]
plt.scatter(heights,weights,color='cyan',marker='H')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.style.use('default')

# %%
heights=[150,155,345,221,904,544,342,321]
weights=[50,45,65,67,39,78,67,49]
plt.scatter(heights,weights,color='cyan',marker='H')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### BAR PLOT
# ##### Displays rectangular bars to compare data values across categories.
# ##### Can show vertical or horizontal bars.
# ##### Created with plt.bar() or plt.barh().

# %%
categories= ['A','B','C','D']
values=[10,20,30,40]
plt.bar(categories,values,color='orange')
plt.title('BAR CHART')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
months=['jan','feb','mar','apr','may']
sales=[200,100,120,432,99]
plt.bar(months,sales,color='yellow'
        )
plt.title('Bar chart ')
plt.show()

# %%
fig, ax = plt.subplots(1,9)
ax[0].plot(x,y)
ax[1].bar(x,y)

plt.show()

# %% [markdown]
# #### HISTOGRAM PLOT
# ##### Shows the distribution of continuous data by grouping it into bins.
# ##### Created with plt.hist()

# %%
import numpy as np
data=np.random.randn(100)
print(data)
plt.hist(data,bins=10,edgecolor='black')
plt.title('histogram of random data')
plt.xlabel('value range')
plt.ylabel('frequency')
plt.show
# Out:
# [-1.51678811  0.32141565 -0.51199657 -2.64535571  1.53470915 -1.18655493
#  -0.22659519 -0.40489743 -0.29099636 -0.56701357 -0.05346363  0.28079784
#  -2.07433185 -0.12398884  0.11233135  0.28653057  0.40103311  0.42854908
#  -1.4290002   0.58110818  0.61363884  1.00871599 -0.11291531  0.87353067
#   0.39597239 -0.03536367 -1.7136678  -0.80641617 -0.20742481 -0.65010085
#  -1.54802588 -0.2132553  -0.62537882 -0.32707214  0.592224    1.75389761
#   0.08398131  0.58077343  0.52648546  0.6703971  -0.71379549  0.07157165
#   0.93025852  1.20724447  0.31443274  1.1247421   0.45584727 -0.32280824
#   0.16757923  0.7003472  -0.05812799  2.01931175  1.45562606  0.9178494
#  -0.04350915  1.962708    0.95741707  0.74921828 -0.68422371  0.7496947
#  -0.85350089 -0.01488365 -0.04004837 -1.21944172  2.37267862 -1.37792309
#  -0.43329094 -0.06608073  1.30556937 -0.15606315  0.58791017 -0.42816862
#  -0.22889209  1.06798685  1.54419892  0.00485469  0.72917198 -0.47223428
# ...

# %%
plt.hist(data,bins=20,color='orange',edgecolor='red')
plt.xlabel('value range')
plt.ylabel('frequency')
plt.title('histogram with 20 bins')
plt.show()

# %%
plt.hist(data,bins=15,color='coral',edgecolor='white',alpha=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### alpha controls the transarency

# %%
dt1=np.random.normal(0,1,100)
dt2=np.random.normal(2,1,100)
plt.hist(dt1,bins=15,alpha=0.6,label='mean 0',edgecolor='white')
plt.hist(dt2,bins=15,alpha=0.6,label='mean 2',edgecolor='white')
plt.legend()
plt.title('Two overlapping histograms')
plt.show()

# %% [markdown]
# ###### dt1=np.random.normal(0,1,100) means that an array named dt1 is created with 100 random numbers drawn from a normal (Gaussian) distribution that has a mean of 0 and a standard deviation of 1.

# %% [markdown]
# #### SCATTER PLOT
# ##### A scatter plot represents individual data points as dots on a graph.
# ##### Each point’s position shows the relationship between x (independent) and y (dependent) variables.

# %%
plt.scatter(x,y,marker='H',s=100,color='coral')

# %%
dt1=np.random.randint(1,100,50)
dt2=np.random.randint(50,150,50)
plt.scatter(dt1,dt2,color='cyan',s=80,marker='o',alpha=0.7)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.grid(True,linestyle=":")
plt.show()

# %%
x=[1,2,3,4,5]
y=[5,3,7,4,1]
plt.scatter(x,y,color='red',s=80,marker='p',alpha=0.6)
plt.title('customized scatter plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.grid(True,linestyle=':')
plt.show()

# %% [markdown]
# ### DAY 3
# #### UNIVARIATE PLOTS
# ##### Focus on analyzing and visualizing a single variable at a time.
# ##### Key goals include describing its distribution, central point (like mean or median), and variability (such as range or standard deviation).

# %% [markdown]
# ##### (a)Histogram

# %%
data=np.random.randn(1000)
plt.hist(data,bins=30,color='skyblue',edgecolor='white')
plt.xlabel('value')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# ##### (b)Boxplot

# %%
plt.boxplot(data,vert=False) # parameter vert controls the orinentation of the boxplot in matplotlib
plt.xlabel('value')
plt.show()

# %% [markdown]
# #### core elements of a boxplot
# ##### Box: The central box shows the interquartile range (IQR), which contains the middle 50% of the data—spanning from Q1 (25th percentile) to Q3 (75th percentile).
# ##### Median Line: A line inside the box marks the dataset’s median (Q2), highlighting the center of the distribution.
# ##### Whiskers: Lines (the “whiskers”) extend outward from the box to the minimum and maximum values within 1.5 times the IQR, summarizing typical data spread.
# ##### Outliers: Data points beyond the whiskers are plotted individually and indicate potential extreme values.
# ##### Min/Max: The smallest and largest values inside the whisker limits are shown as endpoints of the whiskers.

# %%
plt.boxplot([-16,-10,1,2,3,4,5,30,43])
plt.show()

# %% [markdown]
# ##### (c)Violin plot (seaborn)
# ##### Combines box plot with kernel density estimate to show data distribution.
# ##### Reveals data shape, spread, and multiple peaks
# ##### Shows median and interquartile range along with density.

# %%
import seaborn as sns

# %%
sns.violinplot(data,color='lightblue')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >

# %%
df=sns.load_dataset('tips')
sns.violinplot(x=df['day'],y=df['total_bill'])
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(y='day',x='total_bill',data=df,orient='h')
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
ds=sns.load_dataset('titanic')
ds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.violinplot(y='pclass',data=ds,orient='x')
plt.show()

# %%
sns.violinplot(x='sex',y='pclass',data=ds,orient='h')
# Out:
# <Axes: xlabel='sex', ylabel='pclass'>

# %% [markdown]
# ### DAY 4

# %% [markdown]
# #### (d)Univariate KDE (Kernel Density Estimate) plot
# ##### A univariate KDE plot shows the probability density distribution of a single continuous variable.

# %%
ht=np.random.randint(140,180,50)
wt=np.random.randint(40,80,50)
sns.kdeplot(x=ht)
plt.show()

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(x='sepal_length',y='sepal_width',data=iris,color='red',label='iris_verginica')
plt.legend()
plt.grid(True,linestyle=':')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16744\3346967481.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# #### (e)Pairplot
# ##### A pairplot in Seaborn is a handy visualization tool that creates a grid of plots showing relationships between each pair of variables in a dataset.
# ##### Pairplot automatically creates:
# ##### Scatterplots for every pair of numerical columns (off-diagonal).
# ##### Distribution plots (like histograms or KDE) for each single column (diagonal).

# %%
sns.pairplot(iris)
plt.show()

# %% [markdown]
# ##### No hue parameter: (above plotting)
# ##### Diagonal plots: By default, histograms (univariate distribution using plt.hist).
# ##### Off-diagonal: Scatter plots.

# %%
q=sns.pairplot(iris,hue='species')
plt.show()

# %% [markdown]
# ##### With hue parameter: (above plotting)
# ##### Diagonal plots: Switch from histogram to univariate KDE plot.
# ##### Off-diagonal: Scatter plots, with points colored according to hue

# %%
sns.pairplot(iris,hue='species',diag_kind='hist',palette='husl')
plt.show()

# %%
import pandas as pd

# %%
glue_ds=sns.load_dataset('glue')
glue_df=pd.DataFrame(glue_ds)
print(glue_ds)
sns.pairplot(glue_ds,hue='Encoder',palette=['coral','orange','yellow'])
plt.show()
# Out:
#           Model  Year      Encoder  Task  Score
# 0         ERNIE  2019  Transformer  CoLA   75.5
# 1            T5  2019  Transformer  CoLA   71.6
# 2       RoBERTa  2019  Transformer  CoLA   67.8
# 3          BERT  2018  Transformer  CoLA   60.5
# 4   BiLSTM+ELMo  2018         LSTM  CoLA   32.1
# ..          ...   ...          ...   ...    ...
# 59         BERT  2018  Transformer   RTE   70.1
# 60  BiLSTM+ELMo  2018         LSTM   RTE   57.4
# 61  BiLSTM+CoVe  2017         LSTM   RTE   52.7
# 62  BiLSTM+Attn  2017         LSTM   RTE   58.4
# 63       BiLSTM  2017         LSTM   RTE   57.4
#
# [64 rows x 5 columns]
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=vector, **plot_kwargs)
# ...

# %%
print(glue_ds.columns)
# Out:
# Index(['Model', 'Year', 'Encoder', 'Task', 'Score'], dtype='object')

# %%
sns.pairplot(glue_ds,hue='Encoder',diag_kind='hist',palette=['coral','orange','yellow'])
plt.show()
# Out:
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=vector, **plot_kwargs)
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=vector, **plot_kwargs)
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=x, y=y, **kwargs)
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=x, y=y, **kwargs)

# %% [markdown]
# #### ()Displot
# ##### A displot in seaborn is used to visualize the distribution of a dataset, either for a single variable (univariate) or for two variables (bivariate).

# %%
sns.displot(iris)
print(iris)
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##### Look at bars with more than one color stacked/overlapping—this tells you that more than one feature has values in that range.
# ##### Larger bars mean more data points in that bin for that feature.

# %%
sns.displot(x='sepal_length',y='petal_length',data=iris)
plt.show()

# %% [markdown]
# ##### there is a positive relationship/correlation between sepal_length and petal_length—when one is bigger, the other is usually bigger too.
# ##### The darkest bins show where the most data points are concentrated—these are the most common sepal and petal combinations.

# %%
tips=sns.load_dataset('tips')
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(tips)

# %%
sns.displot(tips,bins=10,color='red',kde=True)

# %%
sns.violinplot(iris,ax=ax,color='green')
sns.displot(iris,ax=ax,color='pink',kde=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 sns.violinplot(iris,ax=ax,color='green')
#       2 sns.displot(iris,ax=ax,color='pink',kde=True)
#       3 plt.show()
#
# File d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\categorical.py:1747, in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1744 if p.var_types.get(p.orient) == "categorical" or not native_scale:
#    1745     p.scale_categorical(p.orient, order=order, formatter=formatter)
# -> 1747 p._attach(ax, log_scale=log_scale)
#    1749 # Deprecations to remove in v0.14.0.
# ...

# %%
fig,axes=plt.subplots(2,2)
sns.histplot(tips['total_bill'],ax=axes[0,0],color='red')
sns.violinplot(tips['total_bill'],ax=axes[0,1],color='lightblue')
sns.kdeplot(tips['total_bill'],ax=axes[1,0],color='coral')
sns.kdeplot(x=tips['total_bill'],y=tips['tip'],color='green')
plt.style.use('dark_background')
plt.show()

# %% [markdown]
# #### Categorical relationships
# ##### They describe how one categorical variable relates to another variable, which can be:
# ##### Another categorical variable: Are men more likely than women to buy a product?(gender vs purchaser)
# ##### A numeric variable: Do different days have different average total_bills? (day vs bill amount)

# %%
tips=sns.load_dataset('tips')

plt.bar(tips['total_bill'],tips['tip'])
plt.legend()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21580\3754394564.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.barplot(x=tips['total_bill'],y=tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.pie(tips['total_bill'],label=)
# Out:
# ([<matplotlib.patches.Wedge at 0x238871267b0>,
# ...
#  [Text(1.0999327717632925, 0.012161315764385675, ''),
#   Text(1.0995425550303914, 0.031720177761775756, ''),
#   Text(1.0986666960349951, 0.05414324541018767, ''),
#   Text(1.0966278120904296, 0.0860664960931832, ''),
#   Text(1.0933838818981232, 0.1204644628319533, ''),
#   Text(1.0888985375259488, 0.15588449240976504, ''),
#   Text(1.085176352929359, 0.17997856273160823, ''),
#   Text(1.080709472308638, 0.20510250233087293, ''),
#   Text(1.0747131531856826, 0.23450296025783457, ''),
#   Text(1.069960596142263, 0.25531220633352697, ''),
#   Text(1.065656821952413, 0.2727187889132016, ''),
#   Text(1.0571102239846728, 0.30416767472411477, ''),
#   Text(1.0465060199039808, 0.33885859927811923, ''),
#   Text(1.0387885946112883, 0.36182627835123443, ''),
#   Text(1.0307147611639562, 0.38422269729771136, ''),
#   Text(1.0213228545891082, 0.40853350743109834, ''),
#   Text(1.0126201197847688, 0.42965159490810745, ''),
# ...

# %% [markdown]
# ##### The vertical line through the middle of each bar in this Seaborn barplot is an error bar.
# ##### The error bar shows the uncertainty or variation around the mean value plotted as the height of each bar.

# %% [markdown]
# #### (f)Stripplot
# ##### A strip plot is used to display individual data points for a numerical variable, grouped by categories.

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,dodge=True)
plt.show(
)

# %%
sns.stripplot(x='sepal_length',y='petal_length',data=iris)
plt.xticks(rotation=90) #rotates the x-axis ticks/labels by given degrees.
plt.show()

# %% [markdown]
# #### ()Swarmplot
# ##### Each dot is carefully placed beside others, even if they have the same value. Dots are shifted horizontally so they never cover each other.

# %%
sns.swarmplot(tips)
plt.show()
# Out:
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 50.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 63.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 60.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 72.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ##### But in Strip plot Dots can overlap:If many points have the same (or very similar) value, the dots are drawn in the same position, so they sit on top of each other and become hard to count.

# %%
sns.stripplot(tips)
sns.set_style('dark')
plt.show()

# %% [markdown]
# #### (Jointplot)
# ##### Jointplot (in seaborn) is a visual tool used to show the relationship between two variables, and display each variable’s distribution at the same time.

# %%
sns.jointplot(x='tip',y='total_bill',data=tips)
plt.style.use('default')

# %% [markdown]
# ##### Center: A plot (scatter, histogram, KDE, or regression) displaying how the two variables relate to each other.
# ##### Top & Right Margins: Two extra plots showing the distribution for each individual variable.
# ##### Top = x-axis variable’s distribution (like a histogram).
# ##### Right = y-axis variable’s distribution.

# %% [markdown]
# ### Overlaying two plots:
# #####

# %%
sns.boxplot(x='petal_length', y='petal_width', data=iris)          # Plot the boxplot first
sns.stripplot(x='petal_length', y='petal_width', data=iris,        # Overlay the strip plot
              color='red', alpha=0.5,jitter=True)        # Jitter avoids overlap, red dots, slightly transparent
plt.xticks(rotation=90)
plt.show()

# %%
sns.displot(iris)
sns.swarmplot(iris)
plt.show()
# Out:
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 88.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 92.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 84.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Data_Science\data-science\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 89.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ### DAY 5

# %% [markdown]
# ##### Heatmaps and clustermaps

# %%
flights=sns.load_dataset('flights')
print(flights)
sns.set_style('darkgrid')
sns.barplot(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# <Axes: >

# %%
sns.displot(x='year',y='month',data=flights)

# %% [markdown]
# ### HEATMAP
# ##### A heatmap in Seaborn is a 2D color-coded representation of data values, where each cell’s color shows the magnitude of the value.
# ##### Heatmaps require a 2D matrix or grid format— that's why pivot is used
# ##### heatmaps are often used to visualize correlation matrices.

# %%
data=flights.pivot(index='month',columns='year',values='passengers')
print(data)
plt.figure(figsize=(15,15)) # there's no figsize parameter in heatmap
sns.heatmap(data,cmap='viridis',annot=True)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# ##### .pivot() arranges months as rows and years as columns.
# ##### Each cell color shows the number of passengers.
# ##### annot=True adds the value inside each box.
# ##### cmap controls the color scheme (like 'coolwarm', 'viridis', 'magma', etc.).

# %%
plt.style.use('dark_background')
data=tips.corr(numeric_only=True)
sns.heatmap(data,annot=True)
# Out:
# <Axes: >

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
planets=sns.load_dataset('planets')
print(planets)
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dataset=pd.DataFrame({
    'A':np.arange(10),
    'B':np.random.randint(1,100,10),
    'C':np.random.rand(10)
})
dataset
# Out:
#    A   B         C
# 0  0  31  0.981529
# 1  1  66  0.127172
# 2  2  23  0.240428
# 3  3  99  0.485086
# 4  4  36  0.120869
# 5  5  27  0.800661
# 6  6  67  0.292584
# 7  7  62  0.087929
# 8  8  78  0.038210
# 9  9  46  0.591236

# %%
sns.clustermap(dataset,annot=True,figsize=(4,4))

# %%
iris_data=sns.load_dataset('iris').drop('species',axis=1).corr()
# in drop function the axis=1 parameter is used to drop the species column from the data frame 
sns.heatmap(iris_data,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## CLUSTERMAP
# ##### It is a graphical representation of data where both rows and columns are arranged by similarity using hierarchical clustering.
# ##### It is built on top of a heatmap, so you see a color-coded matrix that helps visualize the values and how they relate to one another.
# ##### The main matrix: Colors represent the value of each cell (often correlation, distances, or simply data values).
# ##### The dendrograms (tree-like diagrams) on the top and side: Show how rows (and columns) are grouped together based on how similar they are.

# %%
iris_data=sns.load_dataset('iris').drop('species',axis=1).corr()
sns.clustermap(iris_data,annot=True,figsize=(6,6))
sns.set_style('darkgrid')

# %% [markdown]
# ##### Dendrograms actually gives you sense on which these column are how much distance apart from each other
# ##### Seaborn actually uses heirarchical agglomerative clustering (HAC) algorithm to produce the dedrograms
# ##### HAC finds and arranges clusters by measuring similarities, merging the closest clusters, and building dendrograms that organize rows and columns for you.
# ##### steps done to dedrograms are:
# ##### 1) Compute distances You can use different distance metrics (e.g., Euclidean, Manhattan).
# ##### 2) Linkage calculation (like average, single, or complete linkage)
# ##### 3) Merge closest clusters
# ##### 4) Build a dendrogram
# ##### 5) Reorder the data matrix

# %%
import matplotlib.pyplot as plt

# Example data
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]

# Scatter plot
plt.scatter(x, y, color='red', label='Data points')

# Line plot (connecting the dots)
plt.plot(x, y, color='blue', label='Line plot')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatterplot with Lineplot')
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example data
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]

# Scatter plot
sns.scatterplot(x=x, y=y, color='red', label='Data points')

# Line plot
sns.lineplot(x=x, y=y, color='blue', label='Line plot')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatterplot with Line')
plt.legend()
plt.show()
